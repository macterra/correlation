# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
data = pd.read_csv('data.csv')
print(data)
# Out:
#             x         y
# 0    2.135190  0.372259
# 1    1.197716 -0.392094
# 2    0.166987  0.084879
# 3    0.406546  1.100091
# 4   -0.785626 -1.235301
# ..        ...       ...
# 995 -0.595583 -0.836285
# 996 -0.725810 -0.949749
# 997  0.332585 -0.738922
# 998 -0.203296  0.495699
# 999 -0.896283 -2.012099
#
# [1000 rows x 2 columns]

# %%
correlation = data['x'].corr(data['y'])
print(f"Correlation between x and y: {correlation}")
# Out:
# Correlation between x and y: 0.49917908092483254

# %%
slope, intercept, r_value, p_value, std_err = linregress(data['x'], data['y'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(data['x'], data['y'], label='Data points')
plt.plot(data['x'], intercept + slope * data['x'], 'r', label='Fitted line')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
